# %% [markdown]
# <a href="https://colab.research.google.com/github/athrxii-lgtm/my--project/blob/main/Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Information



name = "Atheer Abdullah"



course = "Introduction to Data Science"



assignment = "GitHub & Colab Integration"



# Simple Python Example



print("Hello, this is my assignment 🚀")



print(f"Student: {name}")



print(f"Course: {course}")



print(f"Task: {assignment}")



# Simple calculation



numbers = [10, 20, 30, 40]



average = sum(numbers) / len(numbers)



print("Numbers:", numbers)



print("Average:", average)
# Out:
# Hello, this is my assignment 🚀
# Student: Atheer Abdullah
# Course: Introduction to Data Science
# Task: GitHub & Colab Integration
# Numbers: [10, 20, 30, 40]
# Average: 25.0
